# %%
import json
import random
import argparse
from logging import getLogger
import torch
from torch import nn
#from xlm.data.loader import check_data_params, load_data, load_binarized, load_mono_data

# %%
#data_path="data/processed/de-en/train.de.pth"
data_path="test.en.pth"

# %%
def main():
    MAX_VOCAB=64000
    UNK_WORD='<unk>'
    data=torch.load(data_path)
    dico=data['dico']
    sentences=data['sentences']
    positions=data['positions']
    unk_words=data['unk_words']
    #print(len(data['dico']))
    for item in data['dico']:
        print(item)
    
    #print(dico.index('<unk>'))
    #print(f"The length of sentences is {len(sentences)}")
    #print(f"The length of positions is {len(positions)}")
    #for item in sentences[:10]:
    #    print(item)

# %%
if __name__ == '__main__':
    main()
# Out:
# <s>
# </s>
# <pad>
# <unk>
# <special0>
# <special1>
# <special2>
# <special3>
# <special4>
# <special5>
# <special6>
# <special7>
# <special8>
# <special9>
# ,
# .
# the
# a
# to
# "
# of
# and
# in
# de
# 's
# that
# on
# for
# la
# is
# The
# à
# was
# le
# with
# l'
# said
# et
# it
# as
# les
# at
# :
# des
# en
# d'
# he
# by
# )
# be
# (
# I
# have
# from
# -
# his
# has
# are
# un
# an
# du
# est
# not
# une
# will
# who
# pour
# but
# had
# they
# this
# que
# '
# their
# qui
# dans
# were
# been
# or
# more
# au
# 't
# which
# about
# you
# we
# her
# would
# It
# up
# one
# its
# sur
# after
# out
# par
# pas
# ?
# il
# can
# she
# $
# also
# than
# when
# son
# people
# all
# A
# He
# plus
# year
# Le
# over
# But
# there
# into
# time
# se
# qu'
# In
# two
# first
# ce
# last
# s'
# ne
# new
# ont
# could
# avec
# so
# n'
# years
# what
# other
# just
# /
# We
# them
# some
# like
# if
# %
# no
# him
# été
# ;
# La
# do
# our
# only
# y
# aux
# now
# Les
# back
# before
# ...
